# %% [markdown]
# <a href="https://colab.research.google.com/github/Viola-Ritah/coursework/blob/master/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=acbe7cf09872df968d3598b06af22090a9da154fb6b2cce841a7a60f2f6926a9
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %% [markdown]
# Loading Dependecies
# What are dependencies in programming or code? A dependency in programming is an essential functionality, library or piece of code that’s essential for a different part of the code to work. For example, a specific library that a given line of code depends on.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
# loading the Boston Housing data set 
from sklearn.datasets import load_boston

boston = load_boston()
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
# data = independent variables or the x values
# target = dependent variables or the y values
# column names also known as feature_names

data_frame_x = pd.DataFrame(boston.data, columns= boston.feature_names)
data_frame_y = pd.DataFrame(boston.target)

# %%
print (data_frame_y)
# Out:
#         0
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
# getting some statistics from the dataset
data_frame_x.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# initializing the linear ligression model
reg = linear_model.LinearRegression()

# %%
# splitting the data into testing and traing
x_train, x_test, y_train, y_test = train_test_split( data_frame_x, data_frame_y, test_size = 0.33, random_state = 42)

# %%
# training the model with the training data
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# printing coefficients/ weight of columns/features of the model
print(reg.coef_)
# Out:
# [[-1.28749718e-01  3.78232228e-02  5.82109233e-02  3.23866812e+00
#   -1.61698120e+01  3.90205116e+00 -1.28507825e-02 -1.42222430e+00
#    2.34853915e-01 -8.21331947e-03 -9.28722459e-01  1.17695921e-02
#   -5.47566338e-01]]

# %%
# predictions of the test data
y_value_pred = reg.predict(x_test)
print(y_value_pred)
# Out:
# [[28.53469469]
#  [36.6187006 ]
#  [15.63751079]
#  [25.5014496 ]
#  [18.7096734 ]
#  [23.16471591]
#  [17.31011035]
#  [14.07736367]
#  [23.01064388]
#  [20.54223482]
#  [24.91632351]
#  [18.41098052]
#  [-6.52079687]
#  [21.83372604]
#  [19.14903064]
#  [26.0587322 ]
#  [20.30232625]
#  [ 5.74943567]
#  [40.33137811]
#  [17.45791446]
#  [27.47486665]
#  [30.2170757 ]
#  [10.80555625]
#  [23.87721728]
#  [17.99492211]
#  [16.02608791]
#  [23.268288  ]
#  [14.36825207]
#  [22.38116971]
#  [19.3092068 ]
#  [22.17284576]
#  [25.05925441]
#  [25.13780726]
#  [18.46730198]
#  [16.60405712]
#  [17.46564046]
#  [30.71367733]
#  [20.05106788]
#  [23.9897768 ]
#  [24.94322408]
#  [13.97945355]
#  [31.64706967]
#  [42.48057206]
#  [17.70042814]
#  [26.92507869]
#  [17.15897719]
#  [13.68918087]
#  [26.14924245]
#  [20.2782306 ]
#  [29.99003492]
#  [21.21260347]
#  [34.03649185]
#  [15.41837553]
#  [25.95781061]
#  [39.13897274]
#  [22.96118424]
#  [18.80310558]
#  [33.07865362]
# ...

# %%
y_vvalue_pred = reg.predict(x_train)
print(y_vvalue_pred)
# Out:
# [[18.94993353]
#  [15.12731053]
#  [18.84864922]
#  [18.15394415]
#  [22.50564535]
#  [23.22171222]
#  [33.68098217]
#  [22.75783928]
#  [20.40501139]
#  [25.34955323]
#  [30.98742418]
#  [33.42830199]
#  [28.17933071]
#  [ 8.83894203]
#  [ 5.38410234]
#  [12.74387898]
#  [20.20437398]
#  [35.44922496]
#  [33.09708858]
#  [15.69533228]
#  [ 4.05260245]
#  [33.37931044]
#  [21.74074514]
#  [19.16341648]
#  [26.46198705]
#  [18.54564247]
#  [17.80757444]
#  [11.19433728]
#  [32.29487535]
#  [24.60961685]
#  [19.60521546]
#  [19.37170844]
#  [11.72553457]
#  [28.99582967]
#  [21.2364499 ]
#  [32.20118655]
#  [32.62862457]
#  [24.92455724]
#  [21.25006711]
#  [25.34637076]
#  [43.09930467]
#  [30.4175747 ]
#  [32.94863635]
#  [26.83312961]
#  [27.21883589]
#  [15.21084787]
#  [30.87123089]
#  [21.13985219]
#  [31.47258563]
#  [29.01584683]
#  [21.88551469]
#  [23.64803462]
#  [12.458529  ]
#  [35.97470919]
#  [36.47137679]
#  [32.52222834]
#  [ 5.30201104]
#  [20.49346947]
# ...

# %%
# printing the actual values
print(y_test)
# Out:
#         0
# 173  23.6
# 274  32.4
# 491  13.6
# 72   22.8
# 452  16.1
# ..    ...
# 110  21.7
# 321  23.1
# 265  22.8
# 29   21.0
# 262  48.8
#
# [167 rows x 1 columns]

# %%
# check the model performance/accuracy (MSE -mean squared error)
print( np.mean( (y_value_pred - y_test)**2))
# Out:
# 0    20.724023
# dtype: float64

# %%
# check the model performance/accuracy (MSE -mean squared error) and sklearn metrics
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_value_pred))
# Out:
# 20.724023437339717

# %%
y_test
# Out:
#         0
# 173  23.6
# 274  32.4
# 491  13.6
# 72   22.8
# 452  16.1
# ..    ...
# 110  21.7
# 321  23.1
# 265  22.8
# 29   21.0
# 262  48.8
#
# [167 rows x 1 columns]

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 478  10.23300   0.0  18.10   0.0  0.614  6.185  96.7  2.1705  24.0  666.0
# 26    0.67191   0.0   8.14   0.0  0.538  5.813  90.3  4.6820   4.0  307.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172  96.1  5.9505   5.0  311.0
# 492   0.11132   0.0  27.74   0.0  0.609  5.983  83.5  2.1099   4.0  711.0
# 108   0.12802   0.0   8.56   0.0  0.520  6.474  97.1  2.4329   5.0  384.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110   5.0  384.0
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290   3.0  223.0
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440   4.0  280.0
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247  24.0  666.0
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147   5.0  384.0
#
#      PTRATIO       B  LSTAT
# 478     20.2  379.70  18.03
# ...

# %%
y =data_frame_y.values

# %%
x = data_frame_x['AGE'].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-068f2b2aa5f9> in <module>
# ----> 1 x = data_frame_x.feature_names
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'feature_names'

# %%
plt.plot(x,y, color="pink")
plt.show()
